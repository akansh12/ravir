# %% [markdown]
# #### TO DO:
# - Check Dropout hyperparameter
# - Augmentations
# - λ1 = λ2 = 1.0 and λ3 = 0.001
# - 600 epochs and used the Adam optimization algorithm with minibatches of size 6 and an initial learning rate of 0.001 that is reduced by a factor of 2 every 50 epochs

# %%
import numpy as np
import torch
import os
from glob import glob
from PIL import Image
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms
from tqdm.notebook import tqdm
import torch.nn as nn
import albumentations as A


import logging
import os
import sys
import tempfile
from glob import glob

import torch
from PIL import Image
from torch.utils.tensorboard import SummaryWriter

import monai
from monai.data import create_test_image_2d, list_data_collate, decollate_batch
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.transforms import (
    Activations,
    EnsureChannelFirstd,
    AsDiscrete,
    Compose,
    LoadImaged,
    RandCropByPosNegLabeld,
    RandRotate90d,
    ScaleIntensityd,
)
from monai.visualize import plot_2d_or_3d_image

# %%
from model_seg_ravir_net import segRAVIR

# %%
path2train_images = Path("../data/raw_data/RAVIR Dataset/train/training_images")
path2train_mask = Path("../data/processed_data/training_images_masks")
path2test_images = Path("../data/raw_data/RAVIR Dataset/test")

# %%
class ravir_dataset():
    def __init__(self, img_dir, mask_dir, transform = None, data_type = 'train'):
        self.segs_dir = None
        if data_type == 'train':
            self.images_dir = sorted(glob(os.path.join(path2train_images, "*.png")))[:19]
            self.segs_dir = sorted(glob(os.path.join(path2train_mask, "*.npy")))[:19]
        if data_type == "val":
            self.images_dir = sorted(glob(os.path.join(path2train_images, "*.png")))[19:]
            self.segs_dir = sorted(glob(os.path.join(path2train_mask, "*.npy")))[19:]
        self.transform = transform
        
    def __len__(self):
        return len(self.images_dir)
    
    def __getitem__(self, idx):
        img = np.array(Image.open(self.images_dir[idx])).astype('uint8')
        
        if self.segs_dir is not None:
            seg = np.load(self.segs_dir[idx]).astype('uint8')
            img = self.transform(img)
            return img, torch.FloatTensor(seg)
        else:
            img = self.transform(img)
            return img

# %%
train_dataset = ravir_dataset(path2train_images, path2train_mask, transform=transforms.ToTensor(), data_type='train')
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=False)

# %%
for x,y in train_dataset:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([1, 768, 768])
# torch.Size([768, 768, 3])

# %% [markdown]
# ### Normalization

# %%
def get_mean_std(loader):
    channels_sum, channels_squared_sum, num_batches = 0,0,0

    for data,_ in tqdm(loader):
        channels_sum += torch.mean(data, dim = [0,2,3])
        channels_squared_sum += torch.mean(data**2, dim = [0,2,3])
        num_batches += 1

    mean = channels_sum/num_batches
    std = (channels_squared_sum/num_batches - mean**2)**0.5

    return mean, std

# %%
get_mean_std(train_loader)
#(tensor([0.4050]), tensor([0.1407]))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# (tensor([0.4050]), tensor([0.1407]))

# %% [markdown]
# ### new_dataset

# %%
class ravir_dataset():
    def __init__(self, img_dir, mask_dir, transform = None, data_type = 'train'):
        self.segs_dir = None
        if data_type == 'train':
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))[:19]
            self.segs_dir = sorted(glob(os.path.join(mask_dir, "*.npy")))[:19]
        if data_type == "val":
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))[19:]
            self.segs_dir = sorted(glob(os.path.join(mask_dir, "*.npy")))[19:]
        if data_type == 'test':
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))
            
        self.transform = transform
        self.norm_transform = A.Normalize(mean = (0.4050), std = (0.1407))
        
    def __len__(self):
        return len(self.images_dir)
    
    def __getitem__(self, idx):
        img = np.array(Image.open(self.images_dir[idx])).astype('uint8')
        
        if self.segs_dir is not None:
            seg = np.load(self.segs_dir[idx]).astype('uint8')
            augmented = self.transform(image=img, mask=seg)
            img = augmented['image']
            seg = augmented['mask']
            img = self.norm_transform(image = img)['image']
            return torch.tensor(img).unsqueeze(0), torch.FloatTensor(seg)
        else:
            augmented = self.transform(image=img)
            img = augmented['image']
            img = self.norm_transform(image = img)['image']
            return torch.tensor(img).unsqueeze(0)

# %% [markdown]
# ### Transforms and Augmentations

# %%
train_transforms = A.Compose([
    A.RandomSizedCrop(min_max_height=(256, 256), height=256, width=256, p=1),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p = 0.5),
    A.RandomRotate90(p=0.5),
    A.Rotate((-30,30), p = 0.5),
    A.ElasticTransform(p=0.5, alpha=1, sigma=50, alpha_affine=10),
    A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.1, rotate_limit=15, p=0.3),
    A.GridDistortion(p=0.5),
    A.OpticalDistortion(distort_limit=0.8, shift_limit=0.6, p=0.5),
    A.CLAHE(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.RandomGamma(p = 0.5),
    A.GaussianBlur(p = 0.5),
    A.GaussNoise(p = 0.5), 
    
        ])

test_transforms = A.Compose([
    A.Rotate(0, p = 1)
        ])

# %% [markdown]
# ### Dataset and Dataloader

# %%
train_dataset = ravir_dataset(path2train_images, path2train_mask, transform=train_transforms, data_type='train')
print(len(train_dataset))
train_loader = DataLoader(train_dataset, batch_size=6, shuffle=True)

val_dataset = ravir_dataset(path2train_images, path2train_mask, transform=test_transforms, data_type='val')
print(len(val_dataset))
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

test_dataset = ravir_dataset(path2test_images, None, transform=test_transforms, data_type='test')
print(len(test_dataset))
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
# Out:
# 19
# 4
# 19

# %%
for x,y in train_dataset:
    print(x.shape)
    print(y.shape)
    break
# for x,y in val_dataset:
#     print(x.shape)
#     print(y.shape)
#     break
# for x in test_dataset:
#     print(x.shape)
#     break
# Out:
# torch.Size([1, 256, 256])
# torch.Size([256, 256, 3])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x[0].numpy())

# %%
plt.imshow(y)

# %% [markdown]
# ### Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = segRAVIR().to(device)

# %% [markdown]
# ### Loss, Metric and Optimizer

# %%
dice_metric = DiceMetric(include_background=False, reduction="mean", get_not_nans=False)
loss_function_1 = monai.losses.DiceCELoss(softmax=False)
loss_function_2 = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-3)
post_trans = Compose([AsDiscrete(threshold=0.5)])

# %%
scheduler = StepLR(optimizer, step_size=50, gamma=0.5)

# %% [markdown]
# ### Model Training

# %%
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()

writer = SummaryWriter()
epochs = 600

for epoch in range(epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epochs}")
    model.train()
    epoch_loss = 0
    val_epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device).permute(0,3,1,2)
        optimizer.zero_grad()
        out_1, out_2 = model(inputs)
        loss = loss_function_1(out_1, labels) + 0.001*loss_function_2(out_2, inputs)   ### Loss function
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_len = len(train_dataset) // train_loader.batch_size
        print(f"{step}/{epoch_len}, train_loss: {loss.item():.4f}")
        writer.add_scalar("train_loss", loss.item(), epoch_len * epoch + step)
        
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
    scheduler.step()


    model.eval()
    with torch.no_grad():
        val_images = None
        val_labels = None
        val_outputs = None
        val_step = 0
        for val_data in val_loader:
            val_step+=1        
            val_images, val_labels = val_data[0].to(device), val_data[1].to(device).permute(0,3,1,2)
            roi_size = (256, 256)
            sw_batch_size = 4
            val_outputs = sliding_window_inference(val_images, roi_size, sw_batch_size, model)
            val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]

#             val_out_1,val_out_2  = model(val_images)
#             val_loss = loss_function_1(val_out_1,val_labels) + 0.001*loss_function_2(val_out_2, val_images)
#             val_epoch_loss += val_loss.item()
#             epoch_len = len(val_dataset) // val_loader.batch_size
#             print(f"{val_step}/{epoch_len}, val_loss: {val_loss.item():.4f}")
#             writer.add_scalar("val_loss", val_loss.item(), epoch_len * epoch + step)

            # compute metric for current iteration
    
            dice_metric(y_pred=[val_outputs[0][0]], y=val_labels)
        # aggregate the final mean dice result
        metric = dice_metric.aggregate().item()
        # reset the status for next validation round
        dice_metric.reset()
        metric_values.append(metric)
        if metric > best_metric:
            best_metric = metric
            best_metric_epoch = epoch + 1
            torch.save(model.state_dict(), "/scratch/scratch6/akansh12/ravir_data/ravir/temp/seg_ravir.pth")
            print("saved new best metric model")
        print(
            "current epoch: {} current mean dice: {:.4f} best mean dice: {:.4f} at epoch {}".format(
                epoch + 1, metric, best_metric, best_metric_epoch
            )
        )
        writer.add_scalar("val_mean_dice", metric, epoch + 1)
        # plot the last model output as GIF image in TensorBoard with the corresponding image and label
        plot_2d_or_3d_image(val_images, epoch + 1, writer, index=0, tag="image")
        plot_2d_or_3d_image(val_labels, epoch + 1, writer, index=0, tag="label")
        plot_2d_or_3d_image([val_outputs[0][0]], epoch + 1, writer, index=0, tag="output", max_channels = 3)

print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
writer.close()
# Out:
# ----------
# epoch 1/600
# 1/3, train_loss: 1.8098
# 2/3, train_loss: 1.7958
# 3/3, train_loss: 1.7927
# 4/3, train_loss: 1.7553
# epoch 1 average loss: 1.7884
# saved new best metric model
# current epoch: 1 current mean dice: 0.0000 best mean dice: 0.0000 at epoch 1
# ----------
# epoch 2/600
# 1/3, train_loss: 1.7753
# 2/3, train_loss: 1.7676
# 3/3, train_loss: 1.7320
# 4/3, train_loss: 1.6629
# epoch 2 average loss: 1.7344
# saved new best metric model
# current epoch: 2 current mean dice: 0.0166 best mean dice: 0.0166 at epoch 2
# ----------
# epoch 3/600
# 1/3, train_loss: 1.7413
# 2/3, train_loss: 1.7292
# 3/3, train_loss: 1.7233
# 4/3, train_loss: 1.7391
# epoch 3 average loss: 1.7332
# saved new best metric model
# current epoch: 3 current mean dice: 0.0486 best mean dice: 0.0486 at epoch 3
# ----------
# epoch 4/600
# 1/3, train_loss: 1.7157
# 2/3, train_loss: 1.6907
# 3/3, train_loss: 1.6970
# 4/3, train_loss: 1.6250
# epoch 4 average loss: 1.6821
# saved new best metric model
# current epoch: 4 current mean dice: 0.0573 best mean dice: 0.0573 at epoch 4
# ----------
# epoch 5/600
# 1/3, train_loss: 1.6593
# 2/3, train_loss: 1.6560
# 3/3, train_loss: 1.6493
# 4/3, train_loss: 1.6415
# epoch 5 average loss: 1.6515
# saved new best metric model
# current epoch: 5 current mean dice: 0.1398 best mean dice: 0.1398 at epoch 5
# ----------
# epoch 6/600
# 1/3, train_loss: 1.6313
# 2/3, train_loss: 1.6321
# 3/3, train_loss: 1.6367
# 4/3, train_loss: 1.6398
# epoch 6 average loss: 1.6350
# saved new best metric model
# current epoch: 6 current mean dice: 0.1494 best mean dice: 0.1494 at epoch 6
# ----------
# epoch 7/600
# 1/3, train_loss: 1.6449
# 2/3, train_loss: 1.6425
# 3/3, train_loss: 1.5984
# 4/3, train_loss: 1.5981
# epoch 7 average loss: 1.6210
# saved new best metric model
# current epoch: 7 current mean dice: 0.1671 best mean dice: 0.1671 at epoch 7
# ----------
# epoch 8/600
# 1/3, train_loss: 1.5927
# 2/3, train_loss: 1.6163
# 3/3, train_loss: 1.5812
# 4/3, train_loss: 1.5235
# epoch 8 average loss: 1.5784
# saved new best metric model
# current epoch: 8 current mean dice: 0.1846 best mean dice: 0.1846 at epoch 8
# ----------
# epoch 9/600
# 1/3, train_loss: 1.5680
# 2/3, train_loss: 1.5669
# 3/3, train_loss: 1.5508
# 4/3, train_loss: 1.5637
# epoch 9 average loss: 1.5623
# saved new best metric model
# current epoch: 9 current mean dice: 0.2030 best mean dice: 0.2030 at epoch 9
# ----------
# epoch 10/600
# 1/3, train_loss: 1.5834
# 2/3, train_loss: 1.6123
# 3/3, train_loss: 1.5499
# 4/3, train_loss: 1.5292
# epoch 10 average loss: 1.5687
# current epoch: 10 current mean dice: 0.1497 best mean dice: 0.2030 at epoch 9
# ----------
# epoch 11/600
# 1/3, train_loss: 1.5700
# 2/3, train_loss: 1.5775
# 3/3, train_loss: 1.5753
# 4/3, train_loss: 1.5560
# epoch 11 average loss: 1.5697
# saved new best metric model
# current epoch: 11 current mean dice: 0.2221 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 12/600
# 1/3, train_loss: 1.5454
# 2/3, train_loss: 1.5667
# 3/3, train_loss: 1.5347
# 4/3, train_loss: 1.4529
# epoch 12 average loss: 1.5249
# current epoch: 12 current mean dice: 0.2139 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 13/600
# 1/3, train_loss: 1.5354
# 2/3, train_loss: 1.5377
# 3/3, train_loss: 1.5214
# 4/3, train_loss: 1.5415
# epoch 13 average loss: 1.5340
# current epoch: 13 current mean dice: 0.1992 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 14/600
# 1/3, train_loss: 1.5616
# 2/3, train_loss: 1.5425
# 3/3, train_loss: 1.5300
# 4/3, train_loss: 1.5332
# epoch 14 average loss: 1.5418
# current epoch: 14 current mean dice: 0.2138 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 15/600
# 1/3, train_loss: 1.5249
# 2/3, train_loss: 1.5300
# 3/3, train_loss: 1.5064
# 4/3, train_loss: 1.4239
# epoch 15 average loss: 1.4963
# current epoch: 15 current mean dice: 0.2063 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 16/600
# 1/3, train_loss: 1.5099
# 2/3, train_loss: 1.5066
# 3/3, train_loss: 1.4705
# 4/3, train_loss: 1.5514
# epoch 16 average loss: 1.5096
# current epoch: 16 current mean dice: 0.2081 best mean dice: 0.2221 at epoch 11
# ----------
# epoch 17/600
# 1/3, train_loss: 1.5033
# 2/3, train_loss: 1.4838
# 3/3, train_loss: 1.5006
# 4/3, train_loss: 1.4238
# epoch 17 average loss: 1.4779
# saved new best metric model
# current epoch: 17 current mean dice: 0.2306 best mean dice: 0.2306 at epoch 17
# ----------
# epoch 18/600
# 1/3, train_loss: 1.4967
# 2/3, train_loss: 1.5056
# 3/3, train_loss: 1.4445
# 4/3, train_loss: 1.4665
# epoch 18 average loss: 1.4783
# saved new best metric model
# current epoch: 18 current mean dice: 0.2330 best mean dice: 0.2330 at epoch 18
# ----------
# epoch 19/600
# 1/3, train_loss: 1.4477
# 2/3, train_loss: 1.4611
# 3/3, train_loss: 1.4561
# 4/3, train_loss: 1.4798
# epoch 19 average loss: 1.4612
# saved new best metric model
# current epoch: 19 current mean dice: 0.2420 best mean dice: 0.2420 at epoch 19
# ----------
# epoch 20/600
# 1/3, train_loss: 1.4301
# 2/3, train_loss: 1.4920
# 3/3, train_loss: 1.4408
# 4/3, train_loss: 1.3726
# epoch 20 average loss: 1.4339
# current epoch: 20 current mean dice: 0.2246 best mean dice: 0.2420 at epoch 19
# ----------
# epoch 21/600
# 1/3, train_loss: 1.4603
# 2/3, train_loss: 1.4450
# 3/3, train_loss: 1.4430
# 4/3, train_loss: 1.4518
# epoch 21 average loss: 1.4500
# current epoch: 21 current mean dice: 0.1899 best mean dice: 0.2420 at epoch 19
# ----------
# epoch 22/600
# 1/3, train_loss: 1.4370
# 2/3, train_loss: 1.3964
# 3/3, train_loss: 1.4061
# 4/3, train_loss: 1.4341
# epoch 22 average loss: 1.4184
# current epoch: 22 current mean dice: 0.2278 best mean dice: 0.2420 at epoch 19
# ----------
# epoch 23/600
# 1/3, train_loss: 1.3939
# 2/3, train_loss: 1.4135
# 3/3, train_loss: 1.4581
# 4/3, train_loss: 1.3945
# epoch 23 average loss: 1.4150
# current epoch: 23 current mean dice: 0.2086 best mean dice: 0.2420 at epoch 19
# ----------
# epoch 24/600
# 1/3, train_loss: 1.3924
# 2/3, train_loss: 1.4139
# 3/3, train_loss: 1.4020
# 4/3, train_loss: 1.3563
# epoch 24 average loss: 1.3911
# saved new best metric model
# current epoch: 24 current mean dice: 0.2490 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 25/600
# 1/3, train_loss: 1.4023
# 2/3, train_loss: 1.4486
# 3/3, train_loss: 1.4282
# 4/3, train_loss: 1.3545
# epoch 25 average loss: 1.4084
# current epoch: 25 current mean dice: 0.2480 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 26/600
# 1/3, train_loss: 1.4016
# 2/3, train_loss: 1.3857
# 3/3, train_loss: 1.4260
# 4/3, train_loss: 1.4179
# epoch 26 average loss: 1.4078
# current epoch: 26 current mean dice: 0.2165 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 27/600
# 1/3, train_loss: 1.3796
# 2/3, train_loss: 1.3837
# 3/3, train_loss: 1.4153
# 4/3, train_loss: 1.4251
# epoch 27 average loss: 1.4009
# current epoch: 27 current mean dice: 0.1751 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 28/600
# 1/3, train_loss: 1.3996
# 2/3, train_loss: 1.3581
# 3/3, train_loss: 1.4027
# 4/3, train_loss: 1.3990
# epoch 28 average loss: 1.3899
# current epoch: 28 current mean dice: 0.1788 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 29/600
# 1/3, train_loss: 1.3758
# 2/3, train_loss: 1.3772
# 3/3, train_loss: 1.3763
# 4/3, train_loss: 1.3432
# epoch 29 average loss: 1.3681
# current epoch: 29 current mean dice: 0.1105 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 30/600
# 1/3, train_loss: 1.3955
# 2/3, train_loss: 1.3654
# 3/3, train_loss: 1.3938
# 4/3, train_loss: 1.3321
# epoch 30 average loss: 1.3717
# current epoch: 30 current mean dice: 0.1858 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 31/600
# 1/3, train_loss: 1.3661
# 2/3, train_loss: 1.3564
# 3/3, train_loss: 1.3538
# 4/3, train_loss: 1.3167
# epoch 31 average loss: 1.3482
# current epoch: 31 current mean dice: 0.2462 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 32/600
# 1/3, train_loss: 1.3619
# 2/3, train_loss: 1.3838
# 3/3, train_loss: 1.2884
# 4/3, train_loss: 1.3094
# epoch 32 average loss: 1.3359
# current epoch: 32 current mean dice: 0.1935 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 33/600
# 1/3, train_loss: 1.3335
# 2/3, train_loss: 1.3371
# 3/3, train_loss: 1.4001
# 4/3, train_loss: 1.3732
# epoch 33 average loss: 1.3610
# current epoch: 33 current mean dice: 0.1323 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 34/600
# 1/3, train_loss: 1.3260
# 2/3, train_loss: 1.3158
# 3/3, train_loss: 1.3233
# 4/3, train_loss: 1.2496
# epoch 34 average loss: 1.3037
# current epoch: 34 current mean dice: 0.1264 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 35/600
# 1/3, train_loss: 1.3292
# 2/3, train_loss: 1.3208
# 3/3, train_loss: 1.3563
# 4/3, train_loss: 1.3345
# epoch 35 average loss: 1.3352
# current epoch: 35 current mean dice: 0.1652 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 36/600
# 1/3, train_loss: 1.3793
# 2/3, train_loss: 1.3045
# 3/3, train_loss: 1.2887
# 4/3, train_loss: 1.3917
# epoch 36 average loss: 1.3410
# current epoch: 36 current mean dice: 0.1879 best mean dice: 0.2490 at epoch 24
# ----------
# epoch 37/600
# 1/3, train_loss: 1.2903
# 2/3, train_loss: 1.2853
# 3/3, train_loss: 1.2751
# 4/3, train_loss: 1.3836
# epoch 37 average loss: 1.3086
# saved new best metric model
# current epoch: 37 current mean dice: 0.2593 best mean dice: 0.2593 at epoch 37
# ----------
# epoch 38/600
# 1/3, train_loss: 1.2845
# 2/3, train_loss: 1.3008
# 3/3, train_loss: 1.2832
# 4/3, train_loss: 1.2400
# epoch 38 average loss: 1.2771
# saved new best metric model
# current epoch: 38 current mean dice: 0.2665 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 39/600
# 1/3, train_loss: 1.2912
# 2/3, train_loss: 1.3051
# 3/3, train_loss: 1.3185
# 4/3, train_loss: 1.2323
# epoch 39 average loss: 1.2868
# current epoch: 39 current mean dice: 0.2530 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 40/600
# 1/3, train_loss: 1.2998
# 2/3, train_loss: 1.3094
# 3/3, train_loss: 1.2921
# 4/3, train_loss: 1.2056
# epoch 40 average loss: 1.2767
# current epoch: 40 current mean dice: 0.2462 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 41/600
# 1/3, train_loss: 1.2693
# 2/3, train_loss: 1.2712
# 3/3, train_loss: 1.2732
# 4/3, train_loss: 1.3461
# epoch 41 average loss: 1.2900
# current epoch: 41 current mean dice: 0.2510 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 42/600
# 1/3, train_loss: 1.2651
# 2/3, train_loss: 1.2563
# 3/3, train_loss: 1.2698
# 4/3, train_loss: 1.3133
# epoch 42 average loss: 1.2761
# current epoch: 42 current mean dice: 0.2235 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 43/600
# 1/3, train_loss: 1.2540
# 2/3, train_loss: 1.2908
# 3/3, train_loss: 1.2642
# 4/3, train_loss: 1.2040
# epoch 43 average loss: 1.2533
# current epoch: 43 current mean dice: 0.2130 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 44/600
# 1/3, train_loss: 1.2434
# 2/3, train_loss: 1.2716
# 3/3, train_loss: 1.2470
# 4/3, train_loss: 1.2726
# epoch 44 average loss: 1.2587
# current epoch: 44 current mean dice: 0.2278 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 45/600
# 1/3, train_loss: 1.2254
# 2/3, train_loss: 1.2693
# 3/3, train_loss: 1.2589
# 4/3, train_loss: 1.1531
# epoch 45 average loss: 1.2267
# current epoch: 45 current mean dice: 0.2440 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 46/600
# 1/3, train_loss: 1.2588
# 2/3, train_loss: 1.2771
# 3/3, train_loss: 1.2546
# 4/3, train_loss: 1.2075
# epoch 46 average loss: 1.2495
# current epoch: 46 current mean dice: 0.2471 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 47/600
# 1/3, train_loss: 1.2285
# 2/3, train_loss: 1.2068
# 3/3, train_loss: 1.2605
# 4/3, train_loss: 1.3048
# epoch 47 average loss: 1.2501
# current epoch: 47 current mean dice: 0.2463 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 48/600
# 1/3, train_loss: 1.2286
# 2/3, train_loss: 1.2543
# 3/3, train_loss: 1.2555
# 4/3, train_loss: 1.1874
# epoch 48 average loss: 1.2315
# current epoch: 48 current mean dice: 0.2515 best mean dice: 0.2665 at epoch 38
# ----------
# epoch 49/600
# 1/3, train_loss: 1.2319
# 2/3, train_loss: 1.2333
# 3/3, train_loss: 1.2239
# 4/3, train_loss: 1.1966
# epoch 49 average loss: 1.2214
# saved new best metric model
# current epoch: 49 current mean dice: 0.2712 best mean dice: 0.2712 at epoch 49
# ----------
# epoch 50/600
# 1/3, train_loss: 1.2348
# 2/3, train_loss: 1.2159
# 3/3, train_loss: 1.2429
# 4/3, train_loss: 1.2108
# epoch 50 average loss: 1.2261
# current epoch: 50 current mean dice: 0.2604 best mean dice: 0.2712 at epoch 49
# ----------
# epoch 51/600
# 1/3, train_loss: 1.2320
# 2/3, train_loss: 1.1555
# 3/3, train_loss: 1.2692
# 4/3, train_loss: 1.2629
# epoch 51 average loss: 1.2299
# saved new best metric model
# current epoch: 51 current mean dice: 0.2794 best mean dice: 0.2794 at epoch 51
# ----------
# epoch 52/600
# 1/3, train_loss: 1.2327
# 2/3, train_loss: 1.2449
# 3/3, train_loss: 1.2402
# 4/3, train_loss: 1.1379
# epoch 52 average loss: 1.2139
# current epoch: 52 current mean dice: 0.2492 best mean dice: 0.2794 at epoch 51
# ----------
# epoch 53/600
# 1/3, train_loss: 1.2331
# 2/3, train_loss: 1.1723
# 3/3, train_loss: 1.2503
# 4/3, train_loss: 1.1680
# epoch 53 average loss: 1.2059
# current epoch: 53 current mean dice: 0.2112 best mean dice: 0.2794 at epoch 51
# ----------
# epoch 54/600
# 1/3, train_loss: 1.2590
# 2/3, train_loss: 1.2213
# 3/3, train_loss: 1.2154
# 4/3, train_loss: 1.1255
# epoch 54 average loss: 1.2053
# current epoch: 54 current mean dice: 0.2231 best mean dice: 0.2794 at epoch 51
# ----------
# epoch 55/600
# 1/3, train_loss: 1.1818
# 2/3, train_loss: 1.1993
# 3/3, train_loss: 1.2067
# 4/3, train_loss: 1.2665
# epoch 55 average loss: 1.2135
# saved new best metric model
# current epoch: 55 current mean dice: 0.2846 best mean dice: 0.2846 at epoch 55
# ----------
# epoch 56/600
# 1/3, train_loss: 1.2292
# 2/3, train_loss: 1.2168
# 3/3, train_loss: 1.2517
# 4/3, train_loss: 1.0908
# epoch 56 average loss: 1.1971
# current epoch: 56 current mean dice: 0.2387 best mean dice: 0.2846 at epoch 55
# ----------
# epoch 57/600
# 1/3, train_loss: 1.1920
# 2/3, train_loss: 1.2490
# 3/3, train_loss: 1.1739
# 4/3, train_loss: 1.1837
# epoch 57 average loss: 1.1996
# current epoch: 57 current mean dice: 0.1966 best mean dice: 0.2846 at epoch 55
# ----------
# epoch 58/600
# 1/3, train_loss: 1.1699
# 2/3, train_loss: 1.2066
# 3/3, train_loss: 1.1739
# 4/3, train_loss: 1.1396
# epoch 58 average loss: 1.1725
# saved new best metric model
# current epoch: 58 current mean dice: 0.2910 best mean dice: 0.2910 at epoch 58
# ----------
# epoch 59/600
# 1/3, train_loss: 1.2275
# 2/3, train_loss: 1.2081
# 3/3, train_loss: 1.2299
# 4/3, train_loss: 1.2563
# epoch 59 average loss: 1.2304
# saved new best metric model
# current epoch: 59 current mean dice: 0.3757 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 60/600
# 1/3, train_loss: 1.1774
# 2/3, train_loss: 1.2450
# 3/3, train_loss: 1.1415
# 4/3, train_loss: 1.2308
# epoch 60 average loss: 1.1987
# current epoch: 60 current mean dice: 0.2749 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 61/600
# 1/3, train_loss: 1.2476
# 2/3, train_loss: 1.1695
# 3/3, train_loss: 1.1753
# 4/3, train_loss: 1.1771
# epoch 61 average loss: 1.1924
# current epoch: 61 current mean dice: 0.2349 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 62/600
# 1/3, train_loss: 1.2046
# 2/3, train_loss: 1.1816
# 3/3, train_loss: 1.1861
# 4/3, train_loss: 1.2073
# epoch 62 average loss: 1.1949
# current epoch: 62 current mean dice: 0.3078 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 63/600
# 1/3, train_loss: 1.1471
# 2/3, train_loss: 1.2202
# 3/3, train_loss: 1.1428
# 4/3, train_loss: 1.1787
# epoch 63 average loss: 1.1722
# current epoch: 63 current mean dice: 0.3092 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 64/600
# 1/3, train_loss: 1.1569
# 2/3, train_loss: 1.1035
# 3/3, train_loss: 1.2005
# 4/3, train_loss: 1.1518
# epoch 64 average loss: 1.1532
# current epoch: 64 current mean dice: 0.2797 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 65/600
# 1/3, train_loss: 1.2212
# 2/3, train_loss: 1.1720
# 3/3, train_loss: 1.1702
# 4/3, train_loss: 1.1548
# epoch 65 average loss: 1.1795
# current epoch: 65 current mean dice: 0.3180 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 66/600
# 1/3, train_loss: 1.1650
# 2/3, train_loss: 1.1715
# 3/3, train_loss: 1.1802
# 4/3, train_loss: 1.0885
# epoch 66 average loss: 1.1513
# current epoch: 66 current mean dice: 0.3292 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 67/600
# 1/3, train_loss: 1.2058
# 2/3, train_loss: 1.1752
# 3/3, train_loss: 1.1502
# 4/3, train_loss: 1.2300
# epoch 67 average loss: 1.1903
# current epoch: 67 current mean dice: 0.3528 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 68/600
# 1/3, train_loss: 1.1558
# 2/3, train_loss: 1.1179
# 3/3, train_loss: 1.1535
# 4/3, train_loss: 1.1968
# epoch 68 average loss: 1.1560
# current epoch: 68 current mean dice: 0.3615 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 69/600
# 1/3, train_loss: 1.1943
# 2/3, train_loss: 1.2120
# 3/3, train_loss: 1.1701
# 4/3, train_loss: 1.1685
# epoch 69 average loss: 1.1862
# current epoch: 69 current mean dice: 0.3421 best mean dice: 0.3757 at epoch 59
# ----------
# epoch 70/600
# 1/3, train_loss: 1.1853
# 2/3, train_loss: 1.1950

# %%
plt.imshow(out_2[0][0].detach().numpy())

# %%
plt.imshow(labels[0][0].detach().numpy())

# %%
# !tensorboard --logdir=runs
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
