# %% [markdown]
# #### TO DO:
# - Check Dropout hyperparameter
# - ~~Augmentations~~
# - ~~λ1 = λ2 = 1.0 and λ3 = 0.001~~
# - ~~600 epochs and used the Adam optimization algorithm with minibatches of size 6 and an initial learning rate of 0.001 that is reduced by a factor of 2 every 50 epochs~~
# - Remove Normalization

# %%
import numpy as np
import torch
import os
from glob import glob
from PIL import Image
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms
from tqdm.notebook import tqdm
import torch.nn as nn
import albumentations as A


import logging
import os
import sys
import tempfile
from glob import glob

import torch
from PIL import Image
from torch.utils.tensorboard import SummaryWriter

import monai
from monai.data import create_test_image_2d, list_data_collate, decollate_batch
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.transforms import (
    Activations,
    EnsureChannelFirstd,
    AsDiscrete,
    Compose,
    LoadImaged,
    RandCropByPosNegLabeld,
    RandRotate90d,
    ScaleIntensityd,
)
from monai.visualize import plot_2d_or_3d_image

# %%
from model_seg_ravir_net import segRAVIR

# %%
path2train_images = Path("../data/raw_data/RAVIR Dataset/train/training_images")
path2train_mask = Path("../data/processed_data/training_images_masks")
path2test_images = Path("../data/raw_data/RAVIR Dataset/test")

# %%
class ravir_dataset():
    def __init__(self, img_dir, mask_dir, transform = None, data_type = 'train'):
        self.segs_dir = None
        if data_type == 'train':
            self.images_dir = sorted(glob(os.path.join(path2train_images, "*.png")))[:19]
            self.segs_dir = sorted(glob(os.path.join(path2train_mask, "*.npy")))[:19]
        if data_type == "val":
            self.images_dir = sorted(glob(os.path.join(path2train_images, "*.png")))[19:]
            self.segs_dir = sorted(glob(os.path.join(path2train_mask, "*.npy")))[19:]
        self.transform = transform
        
    def __len__(self):
        return len(self.images_dir)
    
    def __getitem__(self, idx):
        img = np.array(Image.open(self.images_dir[idx])).astype('uint8')
        
        if self.segs_dir is not None:
            seg = np.load(self.segs_dir[idx]).astype('uint8')
            img = self.transform(img)
            return img, torch.FloatTensor(seg)
        else:
            img = self.transform(img)
            return img

# %%
train_dataset = ravir_dataset(path2train_images, path2train_mask, transform=transforms.ToTensor(), data_type='train')
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=False)

# %%
for x,y in train_dataset:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([1, 768, 768])
# torch.Size([768, 768, 3])

# %% [markdown]
# ### Normalization

# %%
def get_mean_std(loader):
    channels_sum, channels_squared_sum, num_batches = 0,0,0

    for data,_ in tqdm(loader):
        channels_sum += torch.mean(data, dim = [0,2,3])
        channels_squared_sum += torch.mean(data**2, dim = [0,2,3])
        num_batches += 1

    mean = channels_sum/num_batches
    std = (channels_squared_sum/num_batches - mean**2)**0.5

    return mean, std

# %%
get_mean_std(train_loader)
#(tensor([0.4050]), tensor([0.1407]))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# (tensor([0.4050]), tensor([0.1407]))

# %% [markdown]
# ### new_dataset

# %%
class ravir_dataset():
    def __init__(self, img_dir, mask_dir, transform = None, data_type = 'train'):
        self.segs_dir = None
        if data_type == 'train':
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))[:19]
            self.segs_dir = sorted(glob(os.path.join(mask_dir, "*.npy")))[:19]
        if data_type == "val":
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))[19:]
            self.segs_dir = sorted(glob(os.path.join(mask_dir, "*.npy")))[19:]
        if data_type == 'test':
            self.images_dir = sorted(glob(os.path.join(img_dir, "*.png")))
            
        self.transform = transform
        self.norm_transform = A.Normalize(mean = (0.4050), std = (0.1407))
        
    def __len__(self):
        return len(self.images_dir)
    
    def __getitem__(self, idx):
        img = np.array(Image.open(self.images_dir[idx])).astype('uint8')
        
        if self.segs_dir is not None:
            seg = np.load(self.segs_dir[idx]).astype('uint8')
            augmented = self.transform(image=img, mask=seg)
            img = augmented['image']
            seg = augmented['mask']
            img = self.norm_transform(image = img)['image']
            return torch.tensor(img).unsqueeze(0), torch.FloatTensor(seg)
        else:
            augmented = self.transform(image=img)
            img = augmented['image']
            img = self.norm_transform(image = img)['image']
            return torch.tensor(img).unsqueeze(0)

# %% [markdown]
# ### Transforms and Augmentations

# %%
train_transforms = A.Compose([
    A.RandomSizedCrop(min_max_height=(256, 256), height=256, width=256, p=1),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p = 0.5),
    A.RandomRotate90(p=0.5),
    A.Rotate((-30,30), p = 0.5),
    A.ElasticTransform(p=0.5, alpha=1, sigma=50, alpha_affine=10),
    A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.1, rotate_limit=15, p=0.3),
    A.GridDistortion(p=0.5),
    A.OpticalDistortion(distort_limit=0.8, shift_limit=0.6, p=0.5),
    A.CLAHE(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.RandomGamma(p = 0.5),
    A.GaussianBlur(p = 0.5),
    A.GaussNoise(p = 0.5), 
    
        ])

test_transforms = A.Compose([
    A.Rotate(0, p = 1)
        ])

# %% [markdown]
# ### Dataset and Dataloader

# %%
train_dataset = ravir_dataset(path2train_images, path2train_mask, transform=train_transforms, data_type='train')
print(len(train_dataset))
train_loader = DataLoader(train_dataset, batch_size=6, shuffle=True)

val_dataset = ravir_dataset(path2train_images, path2train_mask, transform=test_transforms, data_type='val')
print(len(val_dataset))
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

test_dataset = ravir_dataset(path2test_images, None, transform=test_transforms, data_type='test')
print(len(test_dataset))
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
# Out:
# 19
# 4
# 19

# %%
for x,y in train_dataset:
    print(x.shape)
    print(y.shape)
    break
# for x,y in val_dataset:
#     print(x.shape)
#     print(y.shape)
#     break
# for x in test_dataset:
#     print(x.shape)
#     break
# Out:
# torch.Size([1, 256, 256])
# torch.Size([256, 256, 3])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x[0].numpy())

# %%
plt.imshow(y)

# %% [markdown]
# ### Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = segRAVIR().to(device)

# %% [markdown]
# ### Loss, Metric and Optimizer

# %%
dice_metric = DiceMetric(include_background=False, reduction="mean", get_not_nans=False)
loss_function_1 = monai.losses.DiceCELoss(softmax=False)
loss_function_2 = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-3)
post_trans = Compose([AsDiscrete(threshold=0.5)])

# %%
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

# %% [markdown]
# ### Model Training

# %% [markdown]
# - Change Dropout

# %%
model.load_state_dict(torch.load("/scratch/scratch6/akansh12/ravir_data/ravir/temp/seg_ravir.pth"))
# Out:
# <All keys matched successfully>

# %%
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()

writer = SummaryWriter()
epochs = 600

for epoch in range(epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epochs}")
    
    model.train()
    epoch_loss = 0
    val_epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device).permute(0,3,1,2)
        optimizer.zero_grad()
        out_1, out_2 = model(inputs)
        loss = loss_function_1(out_1, labels) + 0.001*loss_function_2(out_2, inputs)   ### Loss function
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_len = len(train_dataset) // train_loader.batch_size
        print(f"{step}/{epoch_len}, train_loss: {loss.item():.4f}")
        writer.add_scalar("train_loss", loss.item(), epoch_len * epoch + step)
        
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
    scheduler.step()


    model.eval()
    with torch.no_grad():
        val_images = None
        val_labels = None
        val_outputs = None
        val_step = 0
        for val_data in val_loader:
            val_step+=1        
            val_images, val_labels = val_data[0].to(device), val_data[1].to(device).permute(0,3,1,2)
            roi_size = (256, 256)
            sw_batch_size = 4
            val_outputs = sliding_window_inference(val_images, roi_size, sw_batch_size, model)
            val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]

#             val_out_1,val_out_2  = model(val_images)
#             val_loss = loss_function_1(val_out_1,val_labels) + 0.001*loss_function_2(val_out_2, val_images)
#             val_epoch_loss += val_loss.item()
#             epoch_len = len(val_dataset) // val_loader.batch_size
#             print(f"{val_step}/{epoch_len}, val_loss: {val_loss.item():.4f}")
#             writer.add_scalar("val_loss", val_loss.item(), epoch_len * epoch + step)

            # compute metric for current iteration
    
            dice_metric(y_pred=[val_outputs[0][0]], y=val_labels)
        # aggregate the final mean dice result
        metric = dice_metric.aggregate().item()
        # reset the status for next validation round
        dice_metric.reset()
        metric_values.append(metric)
        if metric > best_metric:
            best_metric = metric
            best_metric_epoch = epoch + 1
            torch.save(model.state_dict(), "/scratch/scratch6/akansh12/ravir_data/ravir/temp/seg_ravir_2.pth")
            print("saved new best metric model")
        print(
            "current epoch: {} current mean dice: {:.4f} best mean dice: {:.4f} at epoch {}".format(
                epoch + 1, metric, best_metric, best_metric_epoch
            )
        )
        writer.add_scalar("val_mean_dice", metric, epoch + 1)
        # plot the last model output as GIF image in TensorBoard with the corresponding image and label
        plot_2d_or_3d_image(val_images, epoch + 1, writer, index=0, tag="image")
        plot_2d_or_3d_image(val_labels, epoch + 1, writer, index=0, tag="label")
        plot_2d_or_3d_image([val_outputs[0][0]], epoch + 1, writer, index=0, tag="output", max_channels = 3)

print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
writer.close()
# Out:
# ----------
# epoch 1/600
# 1/3, train_loss: 0.9902
# 2/3, train_loss: 0.9943
# 3/3, train_loss: 1.0301
# 4/3, train_loss: 0.9441
# epoch 1 average loss: 0.9897
# saved new best metric model
# current epoch: 1 current mean dice: 0.5380 best mean dice: 0.5380 at epoch 1
# ----------
# epoch 2/600
# 1/3, train_loss: 1.0301
# 2/3, train_loss: 1.0017
# 3/3, train_loss: 0.9452
# 4/3, train_loss: 0.9949
# epoch 2 average loss: 0.9930
# current epoch: 2 current mean dice: 0.4997 best mean dice: 0.5380 at epoch 1
# ----------
# epoch 3/600
# 1/3, train_loss: 1.0682
# 2/3, train_loss: 0.9929
# 3/3, train_loss: 1.0518
# 4/3, train_loss: 0.9275
# epoch 3 average loss: 1.0101
# current epoch: 3 current mean dice: 0.5212 best mean dice: 0.5380 at epoch 1
# ----------
# epoch 4/600
# 1/3, train_loss: 1.0200
# 2/3, train_loss: 1.0084
# 3/3, train_loss: 1.0793
# 4/3, train_loss: 1.1626
# epoch 4 average loss: 1.0676
# saved new best metric model
# current epoch: 4 current mean dice: 0.5476 best mean dice: 0.5476 at epoch 4
# ----------
# epoch 5/600
# 1/3, train_loss: 0.9811
# 2/3, train_loss: 0.9812
# 3/3, train_loss: 1.0126
# 4/3, train_loss: 1.1607
# epoch 5 average loss: 1.0339
# saved new best metric model
# current epoch: 5 current mean dice: 0.5616 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 6/600
# 1/3, train_loss: 1.0518
# 2/3, train_loss: 0.9941
# 3/3, train_loss: 0.9526
# 4/3, train_loss: 1.1836
# epoch 6 average loss: 1.0455
# current epoch: 6 current mean dice: 0.5287 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 7/600
# 1/3, train_loss: 1.0461
# 2/3, train_loss: 1.0473
# 3/3, train_loss: 1.0583
# 4/3, train_loss: 1.0326
# epoch 7 average loss: 1.0461
# current epoch: 7 current mean dice: 0.5090 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 8/600
# 1/3, train_loss: 0.9943
# 2/3, train_loss: 1.1069
# 3/3, train_loss: 1.0270
# 4/3, train_loss: 1.1526
# epoch 8 average loss: 1.0702
# current epoch: 8 current mean dice: 0.4891 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 9/600
# 1/3, train_loss: 1.0409
# 2/3, train_loss: 1.0046
# 3/3, train_loss: 1.0608
# 4/3, train_loss: 1.1326
# epoch 9 average loss: 1.0597
# current epoch: 9 current mean dice: 0.4877 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 10/600
# 1/3, train_loss: 1.0702
# 2/3, train_loss: 1.0389
# 3/3, train_loss: 1.0544
# 4/3, train_loss: 0.9333
# epoch 10 average loss: 1.0242
# current epoch: 10 current mean dice: 0.4866 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 11/600
# 1/3, train_loss: 0.9730
# 2/3, train_loss: 1.0009
# 3/3, train_loss: 1.0348
# 4/3, train_loss: 0.9922
# epoch 11 average loss: 1.0002
# current epoch: 11 current mean dice: 0.5086 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 12/600
# 1/3, train_loss: 1.0271
# 2/3, train_loss: 0.9527
# 3/3, train_loss: 0.9936
# 4/3, train_loss: 0.9768
# epoch 12 average loss: 0.9876
# current epoch: 12 current mean dice: 0.5432 best mean dice: 0.5616 at epoch 5
# ----------
# epoch 13/600
# 1/3, train_loss: 0.9876
# 2/3, train_loss: 1.0235
# 3/3, train_loss: 1.0802
# 4/3, train_loss: 0.9772
# epoch 13 average loss: 1.0171
# saved new best metric model
# current epoch: 13 current mean dice: 0.5619 best mean dice: 0.5619 at epoch 13
# ----------
# epoch 14/600
# 1/3, train_loss: 1.0750
# 2/3, train_loss: 0.9951
# 3/3, train_loss: 1.0219
# 4/3, train_loss: 1.0684
# epoch 14 average loss: 1.0401
# saved new best metric model
# current epoch: 14 current mean dice: 0.5715 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 15/600
# 1/3, train_loss: 0.9659
# 2/3, train_loss: 0.9983
# 3/3, train_loss: 1.1562
# 4/3, train_loss: 1.0261
# epoch 15 average loss: 1.0366
# current epoch: 15 current mean dice: 0.5416 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 16/600
# 1/3, train_loss: 1.0183
# 2/3, train_loss: 0.9927
# 3/3, train_loss: 1.0025
# 4/3, train_loss: 1.1863
# epoch 16 average loss: 1.0499
# current epoch: 16 current mean dice: 0.5235 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 17/600
# 1/3, train_loss: 1.0084
# 2/3, train_loss: 1.0898
# 3/3, train_loss: 1.0408
# 4/3, train_loss: 1.2103
# epoch 17 average loss: 1.0873
# current epoch: 17 current mean dice: 0.4671 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 18/600
# 1/3, train_loss: 1.0351
# 2/3, train_loss: 0.9944
# 3/3, train_loss: 1.0096
# 4/3, train_loss: 0.9537
# epoch 18 average loss: 0.9982
# current epoch: 18 current mean dice: 0.4112 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 19/600
# 1/3, train_loss: 0.9509
# 2/3, train_loss: 1.0567
# 3/3, train_loss: 1.0768
# 4/3, train_loss: 1.0661
# epoch 19 average loss: 1.0376
# current epoch: 19 current mean dice: 0.4218 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 20/600
# 1/3, train_loss: 1.0244
# 2/3, train_loss: 1.1070
# 3/3, train_loss: 1.0127
# 4/3, train_loss: 0.9803
# epoch 20 average loss: 1.0311
# current epoch: 20 current mean dice: 0.4295 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 21/600
# 1/3, train_loss: 1.0642
# 2/3, train_loss: 1.0366
# 3/3, train_loss: 0.9851
# 4/3, train_loss: 1.0636
# epoch 21 average loss: 1.0374
# current epoch: 21 current mean dice: 0.4466 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 22/600
# 1/3, train_loss: 1.0411
# 2/3, train_loss: 0.9986
# 3/3, train_loss: 1.0287
# 4/3, train_loss: 0.8870
# epoch 22 average loss: 0.9888
# current epoch: 22 current mean dice: 0.4826 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 23/600
# 1/3, train_loss: 1.0856
# 2/3, train_loss: 0.9888
# 3/3, train_loss: 0.9220
# 4/3, train_loss: 1.1612
# epoch 23 average loss: 1.0394
# current epoch: 23 current mean dice: 0.5244 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 24/600
# 1/3, train_loss: 1.0393
# 2/3, train_loss: 0.9899
# 3/3, train_loss: 1.0321
# 4/3, train_loss: 1.0702
# epoch 24 average loss: 1.0329
# current epoch: 24 current mean dice: 0.5070 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 25/600
# 1/3, train_loss: 0.9128
# 2/3, train_loss: 0.9055
# 3/3, train_loss: 1.1056
# 4/3, train_loss: 0.9287
# epoch 25 average loss: 0.9631
# current epoch: 25 current mean dice: 0.5081 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 26/600
# 1/3, train_loss: 1.0542
# 2/3, train_loss: 1.0231
# 3/3, train_loss: 1.0021
# 4/3, train_loss: 0.9895
# epoch 26 average loss: 1.0172
# current epoch: 26 current mean dice: 0.5581 best mean dice: 0.5715 at epoch 14
# ----------
# epoch 27/600
# 1/3, train_loss: 0.9754
# 2/3, train_loss: 0.9831
# 3/3, train_loss: 1.0625
# 4/3, train_loss: 0.9330
# epoch 27 average loss: 0.9885
# saved new best metric model
# current epoch: 27 current mean dice: 0.5722 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 28/600
# 1/3, train_loss: 0.9770
# 2/3, train_loss: 0.9712
# 3/3, train_loss: 1.0354
# 4/3, train_loss: 1.0525
# epoch 28 average loss: 1.0090
# current epoch: 28 current mean dice: 0.5710 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 29/600
# 1/3, train_loss: 0.9743
# 2/3, train_loss: 0.9912
# 3/3, train_loss: 1.0913
# 4/3, train_loss: 1.1328
# epoch 29 average loss: 1.0474
# current epoch: 29 current mean dice: 0.5594 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 30/600
# 1/3, train_loss: 0.9857
# 2/3, train_loss: 1.0656
# 3/3, train_loss: 0.9827
# 4/3, train_loss: 0.8389
# epoch 30 average loss: 0.9682
# current epoch: 30 current mean dice: 0.5250 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 31/600
# 1/3, train_loss: 1.0438
# 2/3, train_loss: 1.0470
# 3/3, train_loss: 1.0082
# 4/3, train_loss: 1.1814
# epoch 31 average loss: 1.0701
# current epoch: 31 current mean dice: 0.5139 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 32/600
# 1/3, train_loss: 0.9669
# 2/3, train_loss: 1.0727
# 3/3, train_loss: 1.1468
# 4/3, train_loss: 0.9933
# epoch 32 average loss: 1.0449
# current epoch: 32 current mean dice: 0.5341 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 33/600
# 1/3, train_loss: 0.9873
# 2/3, train_loss: 0.9304
# 3/3, train_loss: 1.0195
# 4/3, train_loss: 1.3439
# epoch 33 average loss: 1.0703
# current epoch: 33 current mean dice: 0.5308 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 34/600
# 1/3, train_loss: 1.0549
# 2/3, train_loss: 1.0181
# 3/3, train_loss: 1.0410
# 4/3, train_loss: 0.8784
# epoch 34 average loss: 0.9981
# current epoch: 34 current mean dice: 0.5288 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 35/600
# 1/3, train_loss: 0.9880
# 2/3, train_loss: 0.9285
# 3/3, train_loss: 0.9680
# 4/3, train_loss: 0.8862
# epoch 35 average loss: 0.9427
# current epoch: 35 current mean dice: 0.5266 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 36/600
# 1/3, train_loss: 1.0682
# 2/3, train_loss: 1.0044
# 3/3, train_loss: 0.9552
# 4/3, train_loss: 1.0329
# epoch 36 average loss: 1.0152
# current epoch: 36 current mean dice: 0.5387 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 37/600
# 1/3, train_loss: 1.0855
# 2/3, train_loss: 0.9496
# 3/3, train_loss: 0.9399
# 4/3, train_loss: 0.9369
# epoch 37 average loss: 0.9780
# current epoch: 37 current mean dice: 0.5354 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 38/600
# 1/3, train_loss: 0.9334
# 2/3, train_loss: 1.0564
# 3/3, train_loss: 1.0277
# 4/3, train_loss: 0.9097
# epoch 38 average loss: 0.9818
# current epoch: 38 current mean dice: 0.5542 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 39/600
# 1/3, train_loss: 0.9728
# 2/3, train_loss: 0.9697
# 3/3, train_loss: 0.9654
# 4/3, train_loss: 0.8585
# epoch 39 average loss: 0.9416
# current epoch: 39 current mean dice: 0.5390 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 40/600
# 1/3, train_loss: 0.9699
# 2/3, train_loss: 0.9591
# 3/3, train_loss: 1.0473
# 4/3, train_loss: 1.0181
# epoch 40 average loss: 0.9986
# current epoch: 40 current mean dice: 0.5472 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 41/600
# 1/3, train_loss: 0.9789
# 2/3, train_loss: 1.0448
# 3/3, train_loss: 0.8705
# 4/3, train_loss: 0.9569
# epoch 41 average loss: 0.9628
# current epoch: 41 current mean dice: 0.5612 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 42/600
# 1/3, train_loss: 0.9802
# 2/3, train_loss: 1.0247
# 3/3, train_loss: 1.0193
# 4/3, train_loss: 1.1144
# epoch 42 average loss: 1.0346
# current epoch: 42 current mean dice: 0.5678 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 43/600
# 1/3, train_loss: 1.0264
# 2/3, train_loss: 0.9648
# 3/3, train_loss: 1.0354
# 4/3, train_loss: 0.8761
# epoch 43 average loss: 0.9757
# current epoch: 43 current mean dice: 0.5673 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 44/600
# 1/3, train_loss: 0.9597
# 2/3, train_loss: 0.9867
# 3/3, train_loss: 1.0103
# 4/3, train_loss: 1.1348
# epoch 44 average loss: 1.0229
# current epoch: 44 current mean dice: 0.5509 best mean dice: 0.5722 at epoch 27
# ----------
# epoch 45/600
# 1/3, train_loss: 1.0169
# 2/3, train_loss: 1.0241
# 3/3, train_loss: 1.0143
# 4/3, train_loss: 0.7952
# epoch 45 average loss: 0.9626

# %%
plt.imshow(out_1[0][0].detach().numpy())

# %%
plt.imshow(out_2[0][0].detach().numpy())

# %%
plt.imshow(inputs[0][0].detach().numpy())

# %%
plt.imshow(labels[0][0].detach().numpy())

# %%
# !tensorboard --logdir=runs
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
